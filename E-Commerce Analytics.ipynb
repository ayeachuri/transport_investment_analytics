# %%
# %%html
# <div style="font-family: 'Segoe UI', Arial, sans-serif; max-width: 900px; margin: 0 auto; line-height: 1.6;">
#     <h1 style="color: #2c3e50; border-bottom: 3px solid #3498db; padding-bottom: 10px;">Transport Analysis Project Outline</h1>
#
#     <div style="background-color: #010911; padding: 20px; border-left: 5px solid #3498db; margin: 20px 0;">
#         <h2 style="color: #2c3e50; margin-top: 0;">1. Background</h2>
#         <p style="text-align: justify;">
#             Urban planning and policy has been a curiosity of mine in recent years. While I have been a
#             resident of Singapore for over 20 years, which has been an exemplary case for urban planning
#             given the country's limited area, I've also spent a few years living in North America and India.
#         </p>
#         <p style="text-align: justify;"></p>
#             Canada, where I lived for 5 years, is an example of a nation with broadly car-centric city planning.
#             Characteristic of such urban spaces is the presumptive principle that the default mode of transport to
#             any destination is the car, and accordingly, transport planning focuses on making it easy to move as
#             many cars as possible through a given area quickly and efficiently. Multi-lane freeways, vast parking lots
#             and high speed limits abound, while other modes of transport such as public transit and pedestrian spaces
#             become a secondary consideration. While this maximizes convenience for drivers of personal vehicles, the
#             heavy investment into car-centric infrastructure can often produce results counter to the goal of improving
#             transport quality and efficiency. Some common symptoms include:
#         </p>
#         <ul style="color: #34495e;">
#             <li>The problem of Induced Demand, where adding new highways can actually cause traffic to worsen</li>
#             <li>Adverse effects on health as commuters lose access to destinations that are walkable</li>
#             <li>Safety hazards for pedestrians in high through-put, fast-moving road networks</li>
#             <li>Increased carbon emissions due to the relative inefficiency of people moved per vehicle for personal
#                 cars as opposed to public transit.</li>
#         </ul>
#         <p style="text-align: justify;">
#             Singapore, by contrast, constrained by its limited land, has taken a dramatically different approach
#             to urban mobility, prioritizing public transportation through significant long-term investments in its
#             MRT system and bus networks. Singapore has also taken steps to directly discourage private vehicle ownership
#             through the CoE system in order to improve the passenger density of vehicles on the road. This approach has
#             allowed Singapore to manage congestion despite a very high population density, creating a more livable urban
#             environment, improving health outcomes and reducing transport-related carbon emissions.
#         </p>
#         <p style="text-align: justify;">
#             This exploratory analysis aims to take a more global view on the matter of public transport to explore the
#             relationship between transport infrastructure investments and mobility outcomes in various countries.
#         </p>
#     </div>
#
#     <div style="background-color: #010911; padding: 20px; border-left: 5px solid #e74c3c; margin: 20px 0;">
#         <h2 style="color: #2c3e50; margin-top: 0;">2. Purpose</h2>
#         <p style="font-weight: bold; color: #2c3e50;">We want to explore the following questions:</p>
#
#         <div style="margin-left: 20px; border-left: 3px solid #3498db; padding-left: 15px;">
#             <h3 style="color: #3498db;">Investment Impact</h3>
#             <ul>
#                 <li>How does investment in public transportation correlate with congestion reduction across countries?</li>
#                 <li>How do countries with similar economic profiles but different public transit investments compare over time?
#                     <ul>
#                         <li style="color: #7f8c8d; font-style: italic;">This requires data from new sources and may require clustering techniques.</li>
#                     </ul>
#                 </li>
#             </ul>
#         </div>
#
#         <div style="margin-left: 20px; border-left: 3px solid #27ae60; padding-left: 15px; margin-top: 15px;">
#             <h3 style="color: #27ae60;">Comparing Transport Modes</h3>
#             <ul>
#                 <li>Among countries with the most significant shifts from private to public transit,
#                     what investment patterns preceded these shifts, and how were subsequent measures impacted?</li>
#             </ul>
#         </div>
#
#         <div style="margin-left: 20px; border-left: 3px solid #f39c12; padding-left: 15px; margin-top: 15px;">
#             <h3 style="color: #f39c12;">Economic and Social Returns</h3>
#             <ul>
#                 <li>What's the relationship between public transit investment and economic productivity metrics
#                     across country types?</li>
#             </ul>
#         </div>
#
#         <div style="margin-left: 20px; border-left: 3px solid #9b59b6; padding-left: 15px; margin-top: 15px;">
#             <h3 style="color: #9b59b6;">Environmental Impact</h3>
#             <ul>
#                 <li>What combination of investments has the greatest environmental impact per dollar spent?</li>
#             </ul>
#         </div>
#     </div>
#
#     <div style="background-color: #010911; padding: 20px; border-left: 5px solid #2ecc71; margin: 20px 0;">
#         <h2 style="color: #2c3e50; margin-top: 0;">3. Datasets and Sources</h2>
#         <p>Our primary data source is the <a href="https://data-explorer.oecd.org/vis?lc=en&fs[0]=Topic%2C0%7CTransport%23TRA%23&pg=0&fc=Topic&snb=22&df[ds]=dsDisseminateFinalDMZ&df[id]=DSD_INDICATORS%40DF_TRANSPORTINDICATORS&df[ag]=OECD.ITF&df[vs]=1.0&dq=.A.FREIGHT..ROAD...&lom=LASTNPERIODS&lo=5&to[TIME_PERIOD]=false" style="color: #3498db; text-decoration: none; border-bottom: 1px dotted #3498db;">OECD Data Explorer, Transport Performance Indicators</a></p>
#
#         <div style="background-color: #010911; padding: 15px; border-radius: 5px; margin-top: 15px;">
#             <p style="margin: 0;">This dataset includes more than 90 performance indicators related to transport.</p>
#             <p style="margin: 10px 0 0 0;">The indicators cover seven themes:</p>
#             <div style="display: flex; flex-wrap: wrap; gap: 10px; margin-top: 10px;">
#                 <span style="background-color: #3498db; color: white; padding: 5px 10px; border-radius: 3px;">infrastructure</span>
#                 <span style="background-color: #2ecc71; color: white; padding: 5px 10px; border-radius: 3px;">equipment</span>
#                 <span style="background-color: #e74c3c; color: white; padding: 5px 10px; border-radius: 3px;">activity</span>
#                 <span style="background-color: #f39c12; color: white; padding: 5px 10px; border-radius: 3px;">safety</span>
#                 <span style="background-color: #9b59b6; color: white; padding: 5px 10px; border-radius: 3px;">traffic</span>
#                 <span style="background-color: #1abc9c; color: white; padding: 5px 10px; border-radius: 3px;">economic and social</span>
#                 <span style="background-color: #34495e; color: white; padding: 5px 10px; border-radius: 3px;">environment</span>
#             </div>
#         </div>
#     </div>
# </div>
# Out:
# <div style="font-family: 'Segoe UI', Arial, sans-serif; max-width: 900px; margin: 0 auto; line-height: 1.6;">
#     <h1 style="color: #2c3e50; border-bottom: 3px solid #3498db; padding-bottom: 10px;">Transport Analysis Project Outline</h1>
#
#     <div style="background-color: #010911; padding: 20px; border-left: 5px solid #3498db; margin: 20px 0;">
#         <h2 style="color: #2c3e50; margin-top: 0;">1. Background</h2>
#         <p style="text-align: justify;">
#             Urban planning and policy has been a curiosity of mine in recent years. While I have been a
#             resident of Singapore for over 20 years, which has been an exemplary case for urban planning
#             given the country's limited area, I've also spent a few years living in North America and India.
#         </p>
#         <p style="text-align: justify;"></p>
#             Canada, where I lived for 5 years, is an example of a nation with broadly car-centric city planning.
#             Characteristic of such urban spaces is the presumptive principle that the default mode of transport to
#             any destination is the car, and accordingly, transport planning focuses on making it easy to move as
#             many cars as possible through a given area quickly and efficiently. Multi-lane freeways, vast parking lots
#             and high speed limits abound, while other modes of transport such as public transit and pedestrian spaces
#             become a secondary consideration. While this maximizes convenience for drivers of personal vehicles, the
#             heavy investment into car-centric infrastructure can often produce results counter to the goal of improving
#             transport quality and efficiency. Some common symptoms include:
#         </p>
#         <ul style="color: #34495e;">
#             <li>The problem of Induced Demand, where adding new highways can actually cause traffic to worsen</li>
#             <li>Adverse effects on health as commuters lose access to destinations that are walkable</li>
#             <li>Safety hazards for pedestrians in high through-put, fast-moving road networks</li>
#             <li>Increased carbon emissions due to the relative inefficiency of people moved per vehicle for personal
#                 cars as opposed to public transit.</li>
#         </ul>
#         <p style="text-align: justify;">
#             Singapore, by contrast, constrained by its limited land, has taken a dramatically different approach
#             to urban mobility, prioritizing public transportation through significant long-term investments in its
#             MRT system and bus networks. Singapore has also taken steps to directly discourage private vehicle ownership
#             through the CoE system in order to improve the passenger density of vehicles on the road. This approach has
#             allowed Singapore to manage congestion despite a very high population density, creating a more livable urban
#             environment, improving health outcomes and reducing transport-related carbon emissions.
#         </p>
#         <p style="text-align: justify;">
#             This exploratory analysis aims to take a more global view on the matter of public transport to explore the
#             relationship between transport infrastructure investments and mobility outcomes in various countries.
#         </p>
#     </div>
#
#     <div style="background-color: #010911; padding: 20px; border-left: 5px solid #e74c3c; margin: 20px 0;">
#         <h2 style="color: #2c3e50; margin-top: 0;">2. Purpose</h2>
#         <p style="font-weight: bold; color: #2c3e50;">We want to explore the following questions:</p>
#
#         <div style="margin-left: 20px; border-left: 3px solid #3498db; padding-left: 15px;">
#             <h3 style="color: #3498db;">Investment Impact</h3>
#             <ul>
#                 <li>How does investment in public transportation correlate with congestion reduction across countries?</li>
#                 <li>How do countries with similar economic profiles but different public transit investments compare over time?
#                     <ul>
#                         <li style="color: #7f8c8d; font-style: italic;">This requires data from new sources and may require clustering techniques.</li>
#                     </ul>
#                 </li>
#             </ul>
#         </div>
#
#         <div style="margin-left: 20px; border-left: 3px solid #27ae60; padding-left: 15px; margin-top: 15px;">
#             <h3 style="color: #27ae60;">Comparing Transport Modes</h3>
#             <ul>
#                 <li>Among countries with the most significant shifts from private to public transit,
#                     what investment patterns preceded these shifts, and how were subsequent measures impacted?</li>
#             </ul>
#         </div>
#
#         <div style="margin-left: 20px; border-left: 3px solid #f39c12; padding-left: 15px; margin-top: 15px;">
#             <h3 style="color: #f39c12;">Economic and Social Returns</h3>
#             <ul>
#                 <li>What's the relationship between public transit investment and economic productivity metrics
#                     across country types?</li>
#             </ul>
#         </div>
#
#         <div style="margin-left: 20px; border-left: 3px solid #9b59b6; padding-left: 15px; margin-top: 15px;">
#             <h3 style="color: #9b59b6;">Environmental Impact</h3>
#             <ul>
#                 <li>What combination of investments has the greatest environmental impact per dollar spent?</li>
#             </ul>
#         </div>
#     </div>
#
#     <div style="background-color: #010911; padding: 20px; border-left: 5px solid #2ecc71; margin: 20px 0;">
#         <h2 style="color: #2c3e50; margin-top: 0;">3. Datasets and Sources</h2>
#         <p>Our primary data source is the <a href="https://data-explorer.oecd.org/vis?lc=en&fs[0]=Topic%2C0%7CTransport%23TRA%23&pg=0&fc=Topic&snb=22&df[ds]=dsDisseminateFinalDMZ&df[id]=DSD_INDICATORS%40DF_TRANSPORTINDICATORS&df[ag]=OECD.ITF&df[vs]=1.0&dq=.A.FREIGHT..ROAD...&lom=LASTNPERIODS&lo=5&to[TIME_PERIOD]=false" style="color: #3498db; text-decoration: none; border-bottom: 1px dotted #3498db;">OECD Data Explorer, Transport Performance Indicators</a></p>
#
#         <div style="background-color: #010911; padding: 15px; border-radius: 5px; margin-top: 15px;">
#             <p style="margin: 0;">This dataset includes more than 90 performance indicators related to transport.</p>
#             <p style="margin: 10px 0 0 0;">The indicators cover seven themes:</p>
#             <div style="display: flex; flex-wrap: wrap; gap: 10px; margin-top: 10px;">
#                 <span style="background-color: #3498db; color: white; padding: 5px 10px; border-radius: 3px;">infrastructure</span>
#                 <span style="background-color: #2ecc71; color: white; padding: 5px 10px; border-radius: 3px;">equipment</span>
#                 <span style="background-color: #e74c3c; color: white; padding: 5px 10px; border-radius: 3px;">activity</span>
#                 <span style="background-color: #f39c12; color: white; padding: 5px 10px; border-radius: 3px;">safety</span>
#                 <span style="background-color: #9b59b6; color: white; padding: 5px 10px; border-radius: 3px;">traffic</span>
#                 <span style="background-color: #1abc9c; color: white; padding: 5px 10px; border-radius: 3px;">economic and social</span>
#                 <span style="background-color: #34495e; color: white; padding: 5px 10px; border-radius: 3px;">environment</span>
#             </div>
#         </div>
#     </div>
# </div>

# %%
### Block 1.1 - Data preview ###

# Exploratory Data Analysis

import pandas as pd, numpy as np
import statsmodels.api as sm

allPerformanceIndicatorsDf = pd.read_csv('OECD_Transport_Indicators.csv')

print("Dataframe dimensions: ", allPerformanceIndicatorsDf.shape)
# (89,618, 32)

allPerformanceIndicatorsDf.head(5)
# Out:
# Dataframe dimensions:  (89618, 32)
# C:\Users\Ayeachuri\AppData\Local\Temp\ipykernel_28912\590084345.py:8: DtypeWarning: Columns (26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   allPerformanceIndicatorsDf = pd.read_csv('OECD_Transport_Indicators.csv')
#   STRUCTURE                                       STRUCTURE_ID  \
# 0  DATAFLOW  OECD.ITF:DSD_INDICATORS@DF_TRANSPORTINDICATORS...
# 1  DATAFLOW  OECD.ITF:DSD_INDICATORS@DF_TRANSPORTINDICATORS...
# 2  DATAFLOW  OECD.ITF:DSD_INDICATORS@DF_TRANSPORTINDICATORS...
# 3  DATAFLOW  OECD.ITF:DSD_INDICATORS@DF_TRANSPORTINDICATORS...
# 4  DATAFLOW  OECD.ITF:DSD_INDICATORS@DF_TRANSPORTINDICATORS...
#
#                      STRUCTURE_NAME ACTION REF_AREA Reference area FREQ  \
# 0  Transport performance indicators      I      FIN        Finland    A
# 1  Transport performance indicators      I      FIN        Finland    A
# 2  Transport performance indicators      I      FIN        Finland    A
# 3  Transport performance indicators      I      FIN        Finland    A
# 4  Transport performance indicators      I      FIN        Finland    A
#
#   Frequency of observation  MEASURE            Measure  ... OBS_VALUE  \
# 0                   Annual  FREIGHT  Freight transport  ...  1.848083
# 1                   Annual  FREIGHT  Freight transport  ...  1.576170
# 2                   Annual  FREIGHT  Freight transport  ...  1.792138
# 3                   Annual  FREIGHT  Freight transport  ...  2.316660
# 4                   Annual  FREIGHT  Freight transport  ...  2.059123
#
#   Observation value OBS_STATUS Observation status OBS_STATUS2  \
# 0               NaN        NaN                NaN         NaN
# 1               NaN        NaN                NaN         NaN
# 2               NaN        NaN                NaN         NaN
# 3               NaN        NaN                NaN         NaN
# 4               NaN        NaN                NaN         NaN
#
#   Observation status2 UNIT_MULT Unit multiplier DECIMALS Decimals
# 0                 NaN         0           Units        1      One
# 1                 NaN         0           Units        1      One
# 2                 NaN         0           Units        1      One
# 3                 NaN         0           Units        1      One
# 4                 NaN         0           Units        1      One
#
# [5 rows x 32 columns]

# %%
### Block 1.2 - Data preview ###

allPerformanceIndicatorsDf.describe(include='all')
# The following columns are redundant in the present table (all values are repeated):
# structure_ID, Structure_name, Action, freq, Frequency of observation, Obs_status2, Decimals  

# Several columns are reundancies / transformations of others (e.g. Ref_Area & Reference Area). 
# These are left in the original table as they may be required for joins with other tables
#  from the OECD database, but I want to reduce the dimensions for immediate readability.
# Out:
#        STRUCTURE                                       STRUCTURE_ID  \
# count      89618                                              89618
# unique         1                                                  1
# top     DATAFLOW  OECD.ITF:DSD_INDICATORS@DF_TRANSPORTINDICATORS...
# freq       89618                                              89618
# mean         NaN                                                NaN
# std          NaN                                                NaN
# min          NaN                                                NaN
# 25%          NaN                                                NaN
# 50%          NaN                                                NaN
# 75%          NaN                                                NaN
# max          NaN                                                NaN
#
#                           STRUCTURE_NAME ACTION REF_AREA Reference area  \
# count                              89618  89618    89618          89618
# unique                                 1      1       70             70
# top     Transport performance indicators      I      FIN        Finland
# freq                               89618  89618     2215           2215
# mean                                 NaN    NaN      NaN            NaN
# std                                  NaN    NaN      NaN            NaN
# min                                  NaN    NaN      NaN            NaN
# 25%                                  NaN    NaN      NaN            NaN
# 50%                                  NaN    NaN      NaN            NaN
# 75%                                  NaN    NaN      NaN            NaN
# max                                  NaN    NaN      NaN            NaN
#
#          FREQ Frequency of observation     MEASURE     Measure  ...  \
# count   89618                    89618       89618       89618  ...
# unique      1                        1          23          23  ...
# top         A                   Annual  INVESTMENT  Investment  ...
# freq    89618                    89618       13762       13762  ...
# mean      NaN                      NaN         NaN         NaN  ...
# std       NaN                      NaN         NaN         NaN  ...
# min       NaN                      NaN         NaN         NaN  ...
# 25%       NaN                      NaN         NaN         NaN  ...
# 50%       NaN                      NaN         NaN         NaN  ...
# 75%       NaN                      NaN         NaN         NaN  ...
# max       NaN                      NaN         NaN         NaN  ...
#
#            OBS_VALUE Observation value OBS_STATUS  \
# count   84969.000000               0.0       6506
# unique           NaN               NaN          4
# top              NaN               NaN          M
# freq             NaN               NaN       4624
# mean      129.225913               NaN        NaN
# std       900.656984               NaN        NaN
# min         0.000000               NaN        NaN
# 25%         0.755965               NaN        NaN
# 50%         7.425702               NaN        NaN
# 75%        49.604950               NaN        NaN
# max     20035.475730               NaN        NaN
#
#                       Observation status OBS_STATUS2 Observation status2  \
# count                               6506           8                   8
# unique                                 4           1                   1
# top     Missing value; data cannot exist           B   Time series break
# freq                                4624           8                   8
# mean                                 NaN         NaN                 NaN
# std                                  NaN         NaN                 NaN
# min                                  NaN         NaN                 NaN
# 25%                                  NaN         NaN                 NaN
# 50%                                  NaN         NaN                 NaN
# 75%                                  NaN         NaN                 NaN
# max                                  NaN         NaN                 NaN
#
#        UNIT_MULT Unit multiplier DECIMALS Decimals
# count    89618.0           89618  89618.0    89618
# unique       NaN               1      NaN        1
# top          NaN           Units      NaN      One
# freq         NaN           89618      NaN    89618
# mean         0.0             NaN      1.0      NaN
# std          0.0             NaN      0.0      NaN
# min          0.0             NaN      1.0      NaN
# 25%          0.0             NaN      1.0      NaN
# 50%          0.0             NaN      1.0      NaN
# 75%          0.0             NaN      1.0      NaN
# max          0.0             NaN      1.0      NaN
#
# [11 rows x 32 columns]

# %%
#### Block 1.3 - Data preview ###

#  Creating a subset dataframe for some early visualizations. We track country, metric, measurements, and some associated metadata.

transportIndicatorsDF = allPerformanceIndicatorsDf[
    ['Reference area', 'Measure', 'Unit of measure', 'Transport mode','TIME_PERIOD', 'OBS_VALUE']
    ]

transportIndicatorsDF.head(10)

# The top 10 shows Freight Transport in Finland, by Air, from 1994 to 2003, measured in tonne-kilometeres per 1000USD. 
# It is first worth noting that this is a metric of efficiency, moreso than quantity. An interesting point of study  
# might be to chart cost efficiency against transport infrastructure investment, as well as the country's purchasing power.
# Investing in better roads should cause smoother traffic with fewer breakdowns.
# Countries may also be collecting varying efficiency yields depending on local purchasing power. How does local cost of
# labour and materials correlate with the cost effiency of transport?
# Out:
#   Reference area            Measure                        Unit of measure  \
# 0        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 1        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 2        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 3        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 4        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 5        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 6        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 7        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 8        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 9        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
#
#   Transport mode  TIME_PERIOD  OBS_VALUE
# 0            Air         1994   1.848083
# 1            Air         1995   1.576170
# 2            Air         1996   1.792138
# 3            Air         1997   2.316660
# 4            Air         1998   2.059123
# 5            Air         1999   1.862283
# 6            Air         2000   2.227710
# 7            Air         2001   1.320836
# 8            Air         2002   1.535414
# 9            Air         2003   1.489632

# %%
### Block 1.4 - Data preview ###
 
# However, we also want to gain some idea of the range of values in the table, with respect to different measures, time periods, and values.
transportIndicatorsDF.sample(n=10, replace=False, random_state=32918).head(10)

# This gives us a slightly broader view of the data. Some observations on the table below:
# 1. A decent spread of countries is included, so the data doesn't appear too densely concentrated in any one region.
#       However, plotting individual series of data points for 70 countries may be difficult to interpret. We will   
#       consider clustering countries of similar profiles to analyze results. 
#   <<Data Preparation TASK A>> - optional
# 2. Measure is an instance of 'long' data, with multiple categorical variables tracked within a single column.
#       We may want to pivot/reshape the dataframe later to split each metric into its own column across years.
#   <<Data Preparation TASK B>> - optional, but also a requirement for Data Preparation Task A, as clustering techniques
#       will require each row to represent a unique entity (country) and each column to represent its own metric
# 3. The Unit of measure is a potential convolution in the data. We see that varying measure scales are present 
#       for different measures - e.g. both "per 1000 inhabitants" and "per 1 000 000 inhabitants". We should check
#       the data to make sure all values for a given measure are standardized to the same scale of unit.
#   <<Data Preparation TASK C>> - required
# 4. The main dimensions to slice values across are country, measure, transport mode, and year.
# 5. The 'Unit multiplier' column should theoretically solve the problem in obs #3, but lacks meaningful data. We can 
#       update it to our requirements as needed as part of the Data Preparation process.
# Out:
#                Reference area                                      Measure  \
# 71626                  Sweden            CO2 emissions in transport sector
# 13448               Australia                            Freight transport
# 34350                 Moldova  Available seat capacity for schedule flight
# 49481                 Georgia                                   Investment
# 23122                 Denmark                                        Stock
# 32369                  Sweden                                        Stock
# 80696                  Russia           Fuel deliveries to the road sector
# 15979  Bosnia and Herzegovina                            Freight transport
# 18797              Luxembourg                                        Stock
# 45931                 Austria                                     Airports
#
#                                Unit of measure Transport mode  TIME_PERIOD  \
# 71626              Percentage of CO2 emissions          Total         1997
# 13448          Percentage of freight transport           Road         2005
# 34350                 Per 1 000 000 US dollars            Air         2004
# 49481  Percentage of infrastructure investment           Road         2018
# 23122                    Per 1 000 inhabitants           Road         1998
# 32369                 Per 1 000 000 US dollars           Road         2013
# 80696                        Tonnes per person           Road         2000
# 15979    Tonne-kilometres per 1 000 US dollars           Rail         2008
# 18797                 Per 1 000 000 US dollars           Road         1998
# 45931                Per 1 000 000 inhabitants            Air         2015
#
#        OBS_VALUE
# 71626  36.129864
# 13448  46.874936
# 34350   0.126869
# 49481  88.169274
# 23122   2.622629
# 32369   0.023833
# 80696   0.128243
# 15979  64.982641
# 18797   0.668102
# 45931   0.694228

# %%
### Block 1.5 - Data preview ###

# Let's briefly familiarize ourselves with a few more dimensions of data, namely country, measure, and time period.

transportInvestment = transportIndicatorsDF[(transportIndicatorsDF['Measure'] == 'Investment')]
print("Number of records for the Measure 'Investment': ", transportInvestment.shape)
# (13,762,9)

transportInvestment.describe(include='all')
# Only 54 countries of the original 70 have investment data.
# Out:
# Number of records for the Measure 'Investment':  (13762, 6)
#        Reference area     Measure    Unit of measure Transport mode  \
# count           13762       13762              13762          13762
# unique             54           1                  3              4
# top             Spain  Investment  Percentage of GDP           Road
# freq              308       13762               5080           3807
# mean              NaN         NaN                NaN            NaN
# std               NaN         NaN                NaN            NaN
# min               NaN         NaN                NaN            NaN
# 25%               NaN         NaN                NaN            NaN
# 50%               NaN         NaN                NaN            NaN
# 75%               NaN         NaN                NaN            NaN
# max               NaN         NaN                NaN            NaN
#
#          TIME_PERIOD     OBS_VALUE
# count   13762.000000  11491.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean     2008.591193     67.010384
# std         7.731788    135.552096
# min      1995.000000      0.000000
# 25%      2002.000000      0.518090
# 50%      2009.000000      9.193246
# 75%      2015.000000     75.265920
# max      2023.000000   1286.020745

# %%
### Block 2.1 - Data Preparation ###

# << Data Preparation Task C - Checking 'Unit of measure' values for standardization >>

# 'Measures' and 'Unit of measure' are interrelated columns. The units used for a value
#   are a function of the domain of the 'Measure'.
 
# There are 23 measures across various traffic performance domains.
# There are 31 different 'units of measure' used across these 23 'measures'

# To check for measure consistency, find all unique tuples of ('Measure', 'Unit of measure')  
measureTuples = transportIndicatorsDF[['Measure', 'Unit of measure']].drop_duplicates()
measureTuples.sort_values(by='Measure')
# Out:
#                                                  Measure  \
# 38969                                           Airports
# 38689                                           Airports
# 17154        Available seat capacity for schedule flight
# 17197        Available seat capacity for schedule flight
# 69254                  CO2 emissions in transport sector
# 69198                  CO2 emissions in transport sector
# 69170                  CO2 emissions in transport sector
# 80838                  CO2 emissions in transport sector
# 80808                                            Density
# 62688                 Employment in the transport sector
# 62769  Expenditure for personal transport equipment o...
# 62658                 Expenditure for transport services
# 57913                                         Fatalities
# 57943                                         Fatalities
# 57883                                         Fatalities
# 17167                                First registrations
# 17210                                First registrations
# 0                                      Freight transport
# 28                                     Freight transport
# 80866                 Fuel deliveries to the road sector
# 70370                 Fuel deliveries to the road sector
# 69998                 Fuel deliveries to the road sector
# 62713                Household expenditure for transport
# 60863                              International traffic
# 60871                              International traffic
# 38732                                         Investment
# 38865                                         Investment
# 38790                                         Investment
# 38818                                        Maintenance
# 60859                                   National traffic
# 85                                   Passenger transport
# 17059                                              Stock
# 17029                                              Stock
# 60894                                            Traffic
# 38781                           Transport infrastructure
# 38702                           Transport infrastructure
# 62629                Value added by the transport sector
# 60892                         Vehicle distance travelled
# 62933                                  Vehicle purchases
#
#                                          Unit of measure
# 38969                          Per 100 square kilometres
# 38689                          Per 1 000 000 inhabitants
# 17154                              Per 1 000 inhabitants
# 17197                           Per 1 000 000 US dollars
# 69254                        Percentage of CO2 emissions
# 69198                           Tonnes of CO2 per person
# 69170         Percentage of CO2 emissions from transport
# 80838  Kilogrammes of CO2-equivalent per 1 000 US dol...
# 80808                          Per 100 square kilometres
# 62688                           Percentage of employment
# 62769   Percentage of household expenditure in transport
# 62658   Percentage of household expenditure in transport
# 57913               Per 1 000 000 000 vehicle-kilometres
# 57943                     Per 10 000 road motor vehicles
# 57883                            Per 100 000 inhabitants
# 17167                           Per 1 000 000 US dollars
# 17210                              Per 1 000 inhabitants
# 0                  Tonne-kilometres per 1 000 US dollars
# 28                       Percentage of freight transport
# 80866                    Tonnes per 1 000 000 US dollars
# 70370                                 Tonnes per vehicle
# 69998                                  Tonnes per person
# 62713                Percentage of household expenditure
# 60863               Seat-kilometres per 1 000 US dollars
# 60871                        Percentage of seat capacity
# 38732                              US dollars per person
# 38865                                  Percentage of GDP
# 38790            Percentage of infrastructure investment
# 38818           Percentage of infrastructure maintenance
# 60859               Seat-kilometres per 1 000 US dollars
# 85             Passenger-kilometres per 1 000 US dollars
# 17059                              Per 1 000 inhabitants
# 17029                           Per 1 000 000 US dollars
# 60894            Vehicle-kilometres per 1 000 US dollars
# 38781                         Percentage of road network
# 38702                         Percentage of rail network
# 62629                          Percentage of value added
# 60892                                         Kilometres
# 62933   Percentage of household expenditure in transport

# %%
### Block 2.2 - Data Preparation ###

# Notes on the output of the preceding Block 2.1
# Observation 1:
#   What we see is that Measure:Unit of Measure is an m:n relation
#   Some Measures have multiple Units of measurement (e.g. "Airports"), AND
#   Some Units are used for multiple measures (e.g. "Per 1 000 inhabitants")
# => Plotting values against only Measure or only Unit of Measure can result in data from
#           multiple different metrics. Any analysis should take into account both of 
#           these columns when manipulating or visualizing the data.

# Observation 2:
#   Furthermore, what we see is that while a given Measure does have several Units of 
#   measure, the difference arises not from scale but from the unit. 
#           E.g. The top 2 rows show unit variation: (Airports/area, airports/population)
#   But there are no instances of difference by scale: 
#           E.g. No case of "Stock per thousand inhabitants" AND "Stock per million inhabitants"
# => So there is no need to amend the scales of units as long as measures are considered
#           as a tuple

# The treatment of these two columns as a tuple, however, is an added complexity. We can 
#           simplify this relation by combining each measure-unit pair into a new indentifier.

transportIndicatorsDF.loc[:,'measure-unit'] = (transportIndicatorsDF['Measure'] 
                                               + ': ' 
                                               + transportIndicatorsDF['Unit of measure']
                                               )
transportIndicatorsDF.head()
# It seems natural at this stage to drop the 'Measure' and 'Unit of measure' columns but
# we retain them for filtering utility in future analyses. 

# We now have a standard Measure-Unit column for data analysis. We now proceed to tasks A and B.
# Out:
# C:\Users\Ayeachuri\AppData\Local\Temp\ipykernel_28912\2993339931.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transportIndicatorsDF.loc[:,'measure-unit'] = (transportIndicatorsDF['Measure']
#   Reference area            Measure                        Unit of measure  \
# 0        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 1        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 2        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 3        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
# 4        Finland  Freight transport  Tonne-kilometres per 1 000 US dollars
#
#   Transport mode  TIME_PERIOD  OBS_VALUE  \
# 0            Air         1994   1.848083
# 1            Air         1995   1.576170
# 2            Air         1996   1.792138
# 3            Air         1997   2.316660
# 4            Air         1998   2.059123
#
#                                         measure-unit
# 0  Freight transport: Tonne-kilometres per 1 000 ...
# 1  Freight transport: Tonne-kilometres per 1 000 ...
# 2  Freight transport: Tonne-kilometres per 1 000 ...
# 3  Freight transport: Tonne-kilometres per 1 000 ...
# 4  Freight transport: Tonne-kilometres per 1 000 ...

# %%
### Block 2.3 - Data Preparation ###

# << Data Preparation Task B - Reshaping the dataframe for Cluster analysis >>

# We want to cluster the 70 countries for which we have data into groups for analysis.
# There are 4 main sub-tasks for this:

#  B1. Check for data completeness - do all 70 countries have data on all 39 measure:unit values?
#  B2. Unpivot the measure and time columns so there is exactly one row per country, 
#      reducing 90K rows to ~70
#  B3. Trim the columns so we are only slicing across dimensions which are meaningful for 
#      our analysis. E.g. A measure like "Stock: per 1 000 000 inhabitants" may not be as 
#      interpretable for our clustering compared to "Traffic: Vehicle-kilometers per 1000 USD"
#  B4. Once we have the dataframe reshaped with one country per row, we may also want to 
#      include other meaningful economic indicators as columns, such as GDP per capita, and
#      Purchasing Power Parity, which will also provide meaningful insights into the clusters.


# B1: Checking for Data completeness.

# It is not a given that every country has released data for every metric. Let's run an aggregation
# and plot the findings. We may want to discard metrics if many countries are missing values for it.

# Country metrics aggregation - group countries and aggregate the number of unique "measure-unit" tuples for each
countryMeasuresDF = transportIndicatorsDF.groupby("Reference area").agg({"measure-unit" : pd.Series.nunique}).sort_values("measure-unit")
# This uses reference area as an index, so we reassign the column and assign a new index
print("Countries by number of metrics available:\n", countryMeasuresDF.reset_index())

# While several countries have measures for all 39 tuples, some countries such as the Dominican Republic 
# and Malaysia have just 2. We inspect the data to confirm:

transportIndicatorsDF[(transportIndicatorsDF['Reference area'] == 'Malaysia') | 
                       (transportIndicatorsDF['Reference area'] == 'Dominican Republic') 
                       ].sample(n=12, replace=False, random_state=4218).sort_values('Reference area')
# Malaysia only records passenger and freight transport, and exclusively by Rail transport
# The Dominican Republic only has records for Passenger and freight transport, and exclusively by Air.

print("Plotting countries by number of metrics available: \n", countryMeasuresDF.plot(kind = 'hist', rot = 90))
# Out:
# Countries by number of metrics available:
#          Reference area  measure-unit
# 0   Dominican Republic             2
# 1             Malaysia             2
# 2                 Oman             3
# 3         Saudi Arabia             3
# 4              Tunisia             6
# ..                 ...           ...
# 65              Norway            39
# 66            Portugal            39
# 67              Poland            39
# 68           Lithuania            39
# 69              Latvia            39
#
# [70 rows x 2 columns]
# Plotting countries by number of metrics available:
#  Axes(0.125,0.125;0.775x0.755)

# %%
### Block 2.4 - Data Preparation ###

# << Data Preparation Task B - Reshaping the dataframe for Cluster analysis >>
 
# For the purpose of clustering, we should make sure that all countries are comparable across as many features as possible
# We drop countries which have less than 30 of the 39 measure units.

# Filter countries with at least 30 metrics with a boolean mask
highInfoCountries = countryMeasuresDF[(countryMeasuresDF['measure-unit'] >= 30)].reset_index()

# Using the series above to create a new dataframe with the remaining columns
highInfoCountriesDF = transportIndicatorsDF[
        transportIndicatorsDF['Reference area'].isin(highInfoCountries['Reference area'])
        ]

print("After dropping low-info countries, we are left with a table of dimensions: ", highInfoCountriesDF.shape)
# We still have over 73,000 of the original 89,617 values. 

print("The number of countries included is: ", highInfoCountriesDF['Reference area'].nunique())
# We have reduced to 43 of the original 70 countries.

highInfoCountriesDF.sample(n=10, random_state=4218)

# We now proceed to calculate our metric aggregations and append them as columns here.
# Out:
# After dropping low-info countries, we are left with a table of dimensions:  (73321, 7)
# The number of countries included is:  43
#       Reference area                              Measure  \
# 20118        Finland                  First registrations
# 67800        Germany  Value added by the transport sector
# 28599        Finland                  First registrations
# 68438        Estonia  Household expenditure for transport
# 36152        Belgium                  First registrations
# 36470        Estonia                  First registrations
# 34263     Luxembourg                                Stock
# 36965        Germany                  First registrations
# 55540        Türkiye                           Investment
# 8642          Mexico                    Freight transport
#
#                            Unit of measure Transport mode  TIME_PERIOD  \
# 20118             Per 1 000 000 US dollars           Road         2003
# 67800            Percentage of value added          Total         2004
# 28599                Per 1 000 inhabitants           Road         1997
# 68438  Percentage of household expenditure          Total         2018
# 36152                Per 1 000 inhabitants           Road         2018
# 36470                Per 1 000 inhabitants           Road         2021
# 34263                Per 1 000 inhabitants           Road         2004
# 36965             Per 1 000 000 US dollars           Road         2002
# 55540                US dollars per person         Inland         2005
# 8642       Percentage of freight transport           Road         2021
#
#        OBS_VALUE                                       measure-unit
# 20118   0.002761      First registrations: Per 1 000 000 US dollars
# 67800   4.467049  Value added by the transport sector: Percentag...
# 28599   0.090664         First registrations: Per 1 000 inhabitants
# 68438  11.748241  Household expenditure for transport: Percentag...
# 36152   0.580115         First registrations: Per 1 000 inhabitants
# 36470   0.401974         First registrations: Per 1 000 inhabitants
# 34263  41.046071                       Stock: Per 1 000 inhabitants
# 36965   0.011427      First registrations: Per 1 000 000 US dollars
# 55540  37.948985                  Investment: US dollars per person
# 8642   73.033691  Freight transport: Percentage of freight trans...

# %%
### Block 2.5 - Data Preparation ###

# << Data Preparation Task B - Reshaping the dataframe for Cluster analysis >>

#  B2. Unpivot the measure and time columns so there is exactly one row per country, 
#      reducing 90K rows to ~70

# [X] Filtered out countries with low info; remaining values in highInfoCountriesDF
# [>] Collapse long data in
#       [ ] measure-unit, 
#       [ ] Time_period, 
#       [>] Transport mode

# We pick out a subgroup to examine for aggregation
testDF = highInfoCountriesDF[(highInfoCountriesDF['Reference area'] == 'Finland')
                                & 
                                (highInfoCountriesDF['measure-unit'] == 'Investment: US dollars per person')
                                ]

print(testDF.sort_values("TIME_PERIOD"))

# An oversight - there are multiple observations for each year due to distinct entries for each 'Transport mode'
# I also need to unpivot this column before moving on to unpivot measure-unit and time.

# The path of least resistance to removing the transport modes issue would be to aggregate it all, but having 
# separate measurements for investment by transport mode is a useful indicator of a nation's strategy in public
# transport investment. We will aggregate all the measures except Investment.

# We distinguish the Investment 'measure-units' further to include Transport mode. Other measure-units remain.
investmentRowsMask = (highInfoCountriesDF['Measure'] == 'Investment')

highInfoCountriesDF.loc[investmentRowsMask, 'measure-unit'] = (
    highInfoCountriesDF.loc[investmentRowsMask, 'Measure'] 
    + ' ('
    + highInfoCountriesDF.loc[investmentRowsMask, 'Transport mode']
    + '): '
    + highInfoCountriesDF.loc[investmentRowsMask, 'Unit of measure']
)

# But we still may have other metrics which use the transport modes, so we aggregate those for now
aggHighInfoCountriesDF = highInfoCountriesDF.groupby(['Reference area', 'measure-unit', 'TIME_PERIOD']).agg(
    { "OBS_VALUE" : 'sum',
     }).reset_index()

print("Original hICDF shape: ", highInfoCountriesDF.shape)
print("Aggregate aHICDF shape: ", aggHighInfoCountriesDF.shape) # This has reduced 73321 -> 43747
# Revisiting the Finland data where we spotted the non-aggregated transport investment entries:

aggHighInfoCountriesDF.head()

testDF2 = aggHighInfoCountriesDF[(aggHighInfoCountriesDF['Reference area'] == 'Finland')
                                & # By proxy for the excluded 'Measure' column for Investment
                                (aggHighInfoCountriesDF['measure-unit'] > 'I')
                                & 
                                (aggHighInfoCountriesDF['measure-unit'] < 'J')
                                ]

testDF2.sort_values("TIME_PERIOD") # No repeats!
# Now, (reference area, measure-unit, TIME_PERIOD) should have no repeated tuples and all that remains is aggregation on TIME_PERIOD

# [X] Filtered out countries with low info; remaining values in highInfoCountriesDF
# [>] Collapse long data in 
#       [>] measure-unit, 
#       [>] Time_period, 
#       [X] Transport mode

uniquesCheck = aggHighInfoCountriesDF[['Reference area', 'measure-unit', 'TIME_PERIOD']].drop_duplicates() #should do nothing
print(aggHighInfoCountriesDF.shape[0] == uniquesCheck.shape[0], "- The aggregation consolidated Transport modes.")

# Now that we have our data with just the columns of Index, Time_period, Obs_value and measure-unit, we want to aggregate
# the DF into subgroups of (Reference area, measure-unit), which leaves multiple time_period rows to aggregate across.
# We want to consolidate each column-wise pair ([Time_Period], [Obs_Value]) into a tuple (coefficient, intercept) 

groupedHighInfoCountriesDF = aggHighInfoCountriesDF.groupby(['Reference area', 'measure-unit'])

def olsCoefficients(group):
    # Remove the grouping columns from the group data
    data = group.reset_index(drop=True)
    
    y = data['OBS_VALUE']
    x = data['TIME_PERIOD']
    
    # If we have only one data point, np.polyfit throws rank warnings
    if len(x) == 1:
        # Get the existing value
        obs_value = y.iloc[0]
        year = x.iloc[0]
        
        # Since we have only one point, we define the slope as 0
        # The intercept is just the observed value
        slope = 0
        intercept = obs_value
        
        # Calculate the 2000 prediction (which will be the same as obs_value)
        pred_2000 = intercept  # Since slope is 0, this equals the observed value
        
        return [pred_2000, slope]
    
    # If we have multiple data points, fit the regression
    try:
        slope, intercept = np.polyfit(x, y, 1)
        pred_2000 = slope * 2000 + intercept
        return [pred_2000, slope]
    except:
        # If regression fails for any reason, return NaN
        return [np.nan, np.nan]


result = groupedHighInfoCountriesDF.apply(olsCoefficients, include_groups=False)
result.head(10)

# Convert the result to a dataframe
result_df = pd.DataFrame(result.tolist(), index=result.index, columns=['pred_2000', 'slope'])

# Reset index to convert the MultiIndex into regular columns
final_df = result_df.reset_index()
final_df

# Now pivoting the data wide for each measure-unit:
wide_df_pred = final_df.pivot(index='Reference area', columns='measure-unit', values='pred_2000')
wide_df_slope = final_df.pivot(index='Reference area', columns='measure-unit', values='slope')
wide_df_pred.columns = [f"{col}_pred2000" for col in wide_df_pred.columns]
wide_df_slope.columns = [f"{col}_slope" for col in wide_df_slope.columns]

# Combine them into a single wide DataFrame
wideHighInfoCountriesDF = pd.concat([wide_df_pred, wide_df_slope], axis=1)
wideHighInfoCountriesDF

# We have completed task B2 - unpivot the data. We are left with tasks B3 and B4:

#  B3. Trim the columns so we are only slicing across dimensions which are meaningful for 
#      our analysis. E.g. A measure like "Stock: per 1 000 000 inhabitants" may not be as 
#      interpretable for our clustering compared to "Traffic: Vehicle-kilometers per 1000 USD"
#  B4. Once we have the dataframe reshaped with one country per row, we may also want to 
#      include other meaningful economic indicators as columns, such as GDP per capita, and
#      Purchasing Power Parity, which will also provide meaningful insights into the clusters.
# Out:
# Empty DataFrame
# Columns: [Reference area, Measure, Unit of measure, Transport mode, TIME_PERIOD, OBS_VALUE, measure-unit]
# Index: []
# Original hICDF shape:  (73321, 7)
# Aggregate aHICDF shape:  (43747, 4)
# True - The aggregation consolidated Transport modes.
#                  Airports: Per 1 000 000 inhabitants_pred2000  \
# Reference area
# Australia                                            0.562188
# Austria                                              0.748690
# Azerbaijan                                           0.365606
# Belgium                                              0.392914
# Bulgaria                                             0.310637
# Canada                                               0.976652
# Croatia                                              1.231149
# Czechia                                              0.399407
# Denmark                                              1.139008
# Estonia                                              1.603501
# Finland                                              2.211756
# France                                               0.747766
# Greece           ...
# Hungary          ...
# Iceland          ...
# Ireland          ...
# Israel           ...
# Italy            ...
# Japan            ...
# Korea            ...
# Latvia           ...
# Lithuania        ...
# Luxembourg       ...
# Malta            ...
# Mexico           ...
# Netherlands      ...
# North Macedonia  ...
# Norway           ...
# Poland           ...
# Portugal         ...
# Romania          ...
# Russia           ...
# Serbia           ...
# Slovak Republic  ...
# Slovenia         ...
# Spain            ...
# Sweden           ...
# Switzerland      ...
# Türkiye          ...
# United Kingdom   ...
# United States    ...
#
#                  National traffic: Seat-kilometres per 1 000 US dollars_slope  \
# Reference area
# Australia                                                -2.933803
# Austria                                                   0.011249
# Azerbaijan                                                0.046173
# Belgium                                                   0.000485
# Bulgaria                                                  0.106785
# Canada                                                   -2.054708
# Croatia                                                  -0.256665
# Czechia                                                  -0.030823
# Denmark                                                   0.027617
# Estonia                                                   0.003451
# Finland                                                  -0.508148
# France                                                   -0.105452
# Georgia                                                  -0.039238
# Germany                                                  -0.061323
# Greece                                                   -0.365283
# Hungary                                                        NaN
# Iceland                                                  -0.265913
# Ireland                                                  -0.144048
# Israel                                                   -0.079644
# Italy                                                     0.006629
# Japan                                                     0.299300
# Korea                                                    -0.522558
# Latvia                                                    0.000000
# Lithuania                                                 0.000000
# Luxembourg                                                     NaN
# Malta                                                     0.000000
# Mexico                                                   -0.777410
# Netherlands                                              -0.004786
# North Macedonia                                           0.000000
# Norway                                                   -1.214781
# Poland                                                   -0.049395
# Portugal                                                 -0.422230
# Romania                                                   0.026846
# Russia                                                   -3.603588
# Serbia                                                    0.000000
# Slovak Republic                                          -0.026529
# Slovenia                                                       NaN
# Spain                                                    -1.305317
# Sweden                                                   -0.095604
# Switzerland                                              -0.032970
# Türkiye                                                   2.223665
# United Kingdom                                                 NaN
# United States                                            -2.955729
#
#                  Passenger transport: Passenger-kilometres per 1 000 US dollars_slope  \
# Reference area
# Australia                                               -21.893184
# Austria                                                  -0.602625
# Azerbaijan                                              -90.635675
# Belgium                                                 -17.719790
# Bulgaria                                                -24.585216
# Canada                                                  -30.293906
# Croatia                                                  21.725545
# Czechia                                                 -37.371705
# Denmark                                                 -13.125017
# Estonia                                                  -2.948993
# Finland                                                 -10.238225
# France                                                   -8.490825
# Georgia                                                 -44.303982
# Germany                                                  -9.298416
# Greece                                                  -12.692232
# Hungary                                                 -42.441934
# Iceland                                                  -9.506060
# Ireland                                                  -0.528996
# Israel                                                    0.091530
# Italy                                                   -12.052936
# Japan                                                    -1.711668
# Korea                                                     6.183595
# Latvia                                                   -8.103092
# Lithuania                                                -3.747600
# Luxembourg                                               -0.399466
# Malta                                                     6.857630
# Mexico                                                   -0.077028
# Netherlands                                             -17.391022
# North Macedonia                                           9.814436
# Norway                                                   -9.145807
# Poland                                                  -36.784431
# Portugal                                                -34.560402
# Romania                                                 -19.445071
# Russia                                                  -50.112583
# Serbia                                                   -3.062730
# ...
# Netherlands                                               0.252148
# North Macedonia                                           0.035857
# Norway                                                    0.146529
# Poland                                                    0.497841
# Portugal                                                  1.924962
# Romania                                                   0.122119
# Reference area
# Australia                                         -114.899253
# Austria                                           -113.644372
# Azerbaijan                                                NaN
# Belgium                                            -28.165655
# Bulgaria                                                  NaN
# Canada                                                    NaN
# Croatia                                           -135.365379
# Czechia                                            -79.303133
# Denmark                                           -150.095594
# Estonia                                           -117.111834
# Finland                                           -369.876039
# France                                            -136.644598
# Georgia                                                   NaN
# Germany                                           -314.016408
# Greece                                                    NaN
# Hungary                                             -9.164989
# Iceland                                                   NaN
# Ireland                                           -334.083486
# Israel                                            -247.001872
# Italy                                                     NaN
# Japan                                                     NaN
# Korea                                                     NaN
# Latvia                                            -224.762678
# Lithuania                                          590.723605
# Luxembourg                                         -22.637239
# Malta                                             -121.459592
# Mexico                                                    NaN
# Netherlands                                       -228.864522
# North Macedonia                                           NaN
# Norway                                            -107.815576
# Poland                                            -115.098697
# Portugal                                           -95.684920
# Romania                                           -107.935517
# Russia                                                    NaN
# Serbia                                                    NaN
# Slovak Republic                                           NaN
# Slovenia                                           252.987819
# Spain                                              -50.561129
# Sweden                                            -104.516732
# Switzerland                                        -64.256518
# Türkiye                                            -41.279720
# United Kingdom                                            NaN
# United States                                             NaN
#
#                  Vehicle purchases: Percentage of household expenditure in transport_slope
# Reference area
# Australia                                                -0.310692
# Austria                                                  -0.428516
# Azerbaijan                                                     NaN
# Belgium                                                  -0.034117
# Bulgaria                                                  0.161336
# Canada                                                   -0.060134
# Croatia                                                  -0.385506
# Czechia                                                   0.288260
# Denmark                                                  -0.317526
# Estonia                                                  -0.274871
# Finland                                                  -0.290264
# France                                                   -0.364079
# Georgia                                                        NaN
# Germany                                                  -0.223623
# Greece                                                   -0.561090
# Hungary                                                  -0.428164
# Iceland                                                  -0.697165
# Ireland                                                  -0.378040
# Israel                                                   -0.118003
# Italy                                                    -0.214636
# Japan                                                          NaN
# Korea                                                          NaN
# Latvia                                                    0.184653
# Lithuania                                                 0.246933
# Luxembourg                                               -0.398383
# Malta                                                    -0.549555
# Mexico                                                    0.174330
# Netherlands                                              -0.467094
# North Macedonia                                          -0.248235
# Norway                                                    0.170475
# Poland                                                    0.445858
# Portugal                                                 -0.418171
# Romania                                                   0.439896
# Russia                                                   -1.384025
# Serbia                                                   -0.010431
# Slovak Republic                                          -0.149256
# Slovenia                                                 -0.759143
# Spain                                                    -0.630587
# Sweden                                                    0.004731
# Switzerland                                                    NaN
# Türkiye                                                        NaN
# United Kingdom                                           -0.180087
# United States                                            -0.288664
#
# [43 rows x 94 columns]

# %%
### Block 2.6 - Data Preparation ###

# << Data Preparation Task B - Reshaping the dataframe for Cluster analysis >>

#  B3. Trim the columns so we are only slicing across dimensions which are meaningful for 
#      our analysis. E.g. A measure like "Stock: per 1 000 000 inhabitants" may not be as 
#      interpretable for our clustering compared to "Traffic: Vehicle-kilometers per 1000 USD"

# We examine our columns here:
wideHighInfoCountriesDF.columns

# Some columns are not relevant to our research questions and will be manually dropped. These are:
wideHighInfoCountriesDF.drop([
    'Airports: Per 100 square kilometres_pred2000',
    'Available seat capacity for schedule flight: Per 1 000 000 US dollars_pred2000',
    'Available seat capacity for schedule flight: Per 1 000 inhabitants_pred2000',
    'Airports: Per 100 square kilometres_slope',
    'Available seat capacity for schedule flight: Per 1 000 000 US dollars_slope',
    'Available seat capacity for schedule flight: Per 1 000 inhabitants_slope', 
    'First registrations: Per 1 000 000 US dollars_pred2000',
    'First registrations: Per 1 000 inhabitants_pred2000',
    'Stock: Per 1 000 000 US dollars_slope',
    'Stock: Per 1 000 000 US dollars_pred2000',
    'Stock: Per 1 000 inhabitants_pred2000',
    'Stock: Per 1 000 inhabitants_slope'
    ], axis = "columns", inplace=True) # inplace=True specifies that the original DF is mutated instead of returning a copy
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28912\2501976184.py in <module>
#      11
#      12 # Some columns are not relevant to our research questions and will be manually dropped. These are:
# ---> 13 wideHighInfoCountriesDF.drop([
#      14     'Airports: Per 100 square kilometres_pred2000',
#      15     'Available seat capacity for schedule flight: Per 1 000 000 US dollars_pred2000',
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Airports: Per 100 square kilometres_pred2000', 'Available seat capacity for schedule flight: Per 1 000 000 US dollars_pred2000', 'Available seat capacity for schedule flight: Per 1 000 inhabitants_pred2000', 'Airports: Per 100 square kilometres_slope', 'Available seat capacity for schedule flight: Per 1 000 000 US dollars_slope', 'Available seat capacity for schedule flight: Per 1 000 inhabitants_slope', 'First registrations: Per 1 000 000 US dollars_pred2000', 'First registrations: Per 1 000 inhabitants_pred2000', 'Stock: Per 1 000 000 US dollars_slope', 'Stock: Per 1 000 000 US dollars_pred2000', 'Stock: Per 1 000 inhabitants_pred2000', 'Stock: Per 1 000 inhabitants_slope'] not found in axis"

# %%
### Block 2.7 - Data Preparation ###

# << Data Preparation Task B - Reshaping the dataframe for Cluster analysis >>

wideHighInfoCountriesDF

# We also want to drop columns with high collinearity as they provide diminishing amounts of information
# There are relevant ML methods such as Principle Component Analysis - I'm sure there's an easy way to do this 
# with a python package, but I don't want to include an analysis that I don't yet understand here. This is part
# of an online course that I'm taking and I will revisit it in time. As exercise I follow my curiosity / intuition. 

corrHICDF = wideHighInfoCountriesDF.iloc[:,1:].corr() # A refresher from uni stats - correlation is normalized, covariance is not.
# Default is Pearson, we do not assume Spearman (monotonic) or Kendall (non-linear, ordinal data) 

# Going to just run a loop here since it's a one-off and I don't need to vectorize
# We run through the lower triangle of the covariance matrix for values where |r| > .8
n = corrHICDF.shape[0]
i = 1 
j = 0
while i < n:
    while j < i: # We start the loop at corrHICDF[1,0]
        if abs(corrHICDF.iloc[i,j]) > 0.8:
            print(i,j)
        j += 1
    i += 1

# We get: [15, 14], [28, 27], [29, 28], [70, 69]
# One cannot help but observe that the consecutive columns - it's quite likely that the data involved is causally related

wideHighInfoCountriesDF.iloc[:, [14, 15, 27, 28, 29, 69, 70]]
# 14 and 15: intercept values for Fuel deliveries to the road sector in 2 different metrics (per person, per $)
# We drop per $
# 27, 28, 29: Intercept values for Investment: [Road: USD/person. Waterways: % GDP, Waterways: % Infrastrucutre investment]
# We drop the waterways columns as they have a lot more missing / zero values.
# 69, 70: Slope values for Investment(Road) - USD/person, Investment(Waterways), % of GDP 
# We keep Road investment. Again, the waterways column has far more zero-values.

wideHighInfoCountriesDF.drop([
    'Fuel deliveries to the road sector: Tonnes per 1 000 000 US dollars_pred2000',
    'Investment (Waterways): Percentage of GDP_pred2000',
    'Investment (Waterways): Percentage of infrastructure investment_pred2000',
    'Investment (Waterways): Percentage of GDP_slope'
    ], 
    axis = "columns", 
    inplace=True)
# Out:
# 14 13
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28912\4279689330.py in <module>
#      36 # We keep Road investment. Again, the waterways column has far more zero-values.
#      37
# ---> 38 wideHighInfoCountriesDF.drop([
#      39     'Fuel deliveries to the road sector: Tonnes per 1 000 000 US dollars_pred2000',
#      40     'Investment (Waterways): Percentage of GDP_pred2000',
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Fuel deliveries to the road sector: Tonnes per 1 000 000 US dollars_pred2000', 'Investment (Waterways): Percentage of GDP_pred2000', 'Investment (Waterways): Percentage of infrastructure investment_pred2000', 'Investment (Waterways): Percentage of GDP_slope'] not found in axis"

# %%
# We begin with task B1.  Unpivoting /aggregating measure and time data. 

# To do this, we want each row to represent a single country, reducing 90K rows to 70. 
#   Each measure must then have its own column.
#   We store the output in a separate dataframe that will only be used for clustering.

# A critical consideration now is the dimension of time. For each measure-unit, observations are 
#   recorded annually, with up to 30 values from 1994 to 2023. To store every year in a wide
#   format would mean having up to 30 variants of each measure's column (e.g. stock-1994, stock-1995,
#   ..., stock-2023) For each measure-unit, which results in a multitude of low-information columns.
#   Instead, we summarize the country's attributes with a linear model of a given indicator
#       (While we could also consider an exponential model for some measures such as GDP, most
#        measures in our data are composite measures of proportion and relative rates; linear suffices)
#   e.g. for Airport density, we summarize all years as a linear function (with OLS regression)
#       Airport density Y in year x = m*(x-1994) + b
#       We record in one column: measure-intercept-in-2000 
#         **This will solely be based on the linear approximation, not the data point for 2000
#       We record in the next column: measure-annual-diff 
#   With this linear model, we can also mitigate issues of incomplete / non-parallel time ranges.
#   E.g. If a time series is missing values for certain years, or is biased towards more recent
#       years, as long as we have sufficient data points we can extrapolate for a value in a
#       standardized year (we abritrarily select 2000). 

# Now thinking through the data transformation process:
# We want to: 
# (1) unpivot the metrics into separate columns, 
# (2) aggregate and unpivot metrics for each year into a [intercept, annual trend (%)] format
#       - This will either be stored as a tuple for each unit-measure OR as two columns
# Using pandas' pivot function too early will result in too many columns. I will begin by 
#       storing aggregations in a separate dataframe first.

measureAggregationsDf = transportIndicatorsDF[['Reference area', 'measure-unit']].drop_duplicates()
measureAggregationsDf.sort_values('Reference area').head(10)
# Out:
#       Reference area                                       measure-unit
# 64416        Albania  Household expenditure for transport: Percentag...
# 38781        Albania  Transport infrastructure: Percentage of road n...
# 26037        Albania  Available seat capacity for schedule flight: P...
# 43143        Albania                Airports: Per 100 square kilometres
# 69792        Albania  CO2 emissions in transport sector: Percentage ...
# 86994        Albania  Transport infrastructure: Percentage of rail n...
# 7856         Albania  Freight transport: Tonne-kilometres per 1 000 ...
# 75238        Albania  CO2 emissions in transport sector: Tonnes of C...
# 53841        Albania                Airports: Per 1 000 000 inhabitants
# 797          Albania  Passenger transport: Passenger-kilometres per ...
